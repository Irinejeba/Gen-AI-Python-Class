# %%
# %% [markdown]
# ### Exception Handling (Error Handling)

# %%
# SyntaxError / NameError Example
# Note: Original code had "Print('hello world')" which causes a NameError
# print("hello world") 

# %%
# Basic Exception
print("Few lines above")
num = int(input("Enter a number: "))
print(f"The user enterd number is = {num}")
print("Few lines below")

# %%
# Handling a Basic Exception
print("Few lines above")
try:
    num = int(input("Enter a number: "))
    print(f"The user enterd number is = {num}")
except:
    print("Error handling is done here")
print("Few lines below")

# %% [markdown]
# ### Getting input from user with Error Handling (Loops)

# %%
print("Few lines above")
while True:
    try:
        num = int(input("Enter a number: "))
        print(f"The user enterd number is = {num}")
        break
    except:
        print("Please Enter a Integer Number eg, -99, 100, -662345")
print("Few lines below")

# %%
# Common Exception Base class to store the error message
print("Few lines above")
while True:
    try:
        num1 = int(input("Enter a number: "))
        print(f"The User Entered Number is = {num1}")
        break
    except Exception as e:
        print(e)
print("Few lines below")

# %% [markdown]
# ### Dividing a number with Error Handling

# %%
print(10/2)
print(10/5)
# print(10/0) # Raises ZeroDivisionError: division by zero

# %%
print("Few lines above")
try:
    num1 = int(input("Enter a Dividend number: "))
    print(f"The User Entered Dividend Number is = {num1}")
    num2 = int(input("Enter a Divisor number: "))
    print(f"The User Entered Divisor Number is = {num2}")
    quotient = num1 / num2
    print(f"The Quotient of {num1}/{num2} = {quotient}")
except ValueError:
    print("You gave wrong input type")
except ZeroDivisionError:
    print("Dont divide by zero")
print("Few lines below")

# %%
# Division Error Handling inside a Loop
print("Few lines above")
while True:
    try:
        num1 = int(input("Enter a Dividend number: "))
        print(f"The User Entered Dividend Number is = {num1}")
        num2 = int(input("Enter a Divisor number: "))
        print(f"The User Entered Divisor Number is = {num2}")
        quotient = num1 / num2
        print(f"The Quotient of {num1}/{num2} = {quotient}")
        break
    except ValueError:
        print("You gave wrong input type, Please enter the numbers again")
    except ZeroDivisionError:
        print("Dont divide by zero, Please enter the numbers again")
print("Few lines below")

# %% [markdown]
# ### finally, else, and raise blocks

# %%
# finally block
print("Few lines above")
try:
    num1 = int(input("Enter a number: "))
    print(f"The User Entered Number is = {num1}")
except:
    print("Error handling is done here")
finally:
    print("This line will always work")
print("Few lines below")

# %%
# Error occurring during an exception handling block
print("Few lines above")
try:
    num1 = int(input("Enter a number: "))
    print(f"The User Entered Number is = {num1}")
except:
    print("Error handling is done here")
    # print(10/0) # Raises ZeroDivisionError while in exception clause
print("Few lines below")

# %%
print("Few lines above")
try:
    num1 = int(input("Enter a number: "))
    print(f"The User Entered Number is {num1}")
except:
    print("Error handling is done here")
    # print(5/0)
finally:
    print("Few lines below")
print("Hello Python")

# %%
# The else block works only if try has no errors
print("Few lines above")
try:
    num1 = int(input("Enter a number: "))
    print(f"The User Entered Number is = {num1}")
except:
    print("Error handling is done here")
else:
    print("Executes since try has no errors")
print("Few lines below")

# %%
# raise - keyword
print("Few lines above")
# raise ValueError # Commment/uncomment to test raising raw exceptions
print("Few lines below")

# %%
print("Few lines above")
# raise ValueError("Hi I am raising my error message")
print("Few lines below")

# %%
# Error Handling with Custom Constraints using raise
num = int(input("Enter a number inbetween 10-50: "))
if num < 10:
    raise ValueError
elif num > 50:
    raise ZeroDivisionError
else:
    print(f"Thank you for entering the = {num}")

# %%
# Handling error with raise & Except
while True:
    try:
        num = int(input("Enter a number inbetween 10-50: "))
        if num <= 10:
            raise ValueError
        elif num >= 50:
            raise ZeroDivisionError
        else:
            print(f"Thank you for entering the {num}")
            break
    except ValueError:
        print("Please Enter a number greater than or equal to 10")
    except ZeroDivisionError:
        print("Please Enter a number lesser than or equal to 50")

# %%
# Handling error with raise, Except & 'as' keyword
while True:
    try:
        num = int(input("Enter a number inbetween 10-50: "))
        if num < 10:
            raise ValueError("Please Enter a number greater than or equal to 10")
        elif num > 50:
            raise ZeroDivisionError("Please Enter a number lesser than or equal to 50")
        else:
            print(f"Thank you for entering the = {num}")
            break
    except ValueError as x:
        print(x)
    except ZeroDivisionError as y:
        print(y)

# %% [markdown]
# ### assert - keyword

# %%
x = 5
# assert x < 3 # Will throw AssertionError because 5 is not < 3

# %%
x = 3
# assert x > 5, "my value is lesser than 5"

# %%
while True:
    try:
        num = int(input("Enter a number between 10-50: "))
        assert num >= 10 and num <= 50, "Please provide a number inbetween 10-50"
        print(f"Thank you for entering the = {num}")
        break
    except Exception as e:
        print(e)

# %% [markdown]
# ### Nested Error Handling

# %%
try:
    print("Outer try block")
    try:
        num = int(input("Enter a number: "))
        result = 10 / num
        print(result)
    except ValueError:
        print("Inner Error: Invalid input (not a number)")
    except ZeroDivisionError:
        print("Inner Error: Cannot divide by zero")
except Exception as e:
    print("Outer Error:", e)

# %%
# Real-Time Example (Dividend & Divisor loop with alias)
print("Few lines above")
while True:
    try:
        num1 = int(input("Enter a Dividend number: "))
        print(f"The User Entered Dividend Number is {num1}")
        num2 = int(input("Enter a Divisor number: "))
        print(f"The User Entered Divisor Number is {num2}")
        quotient = num1 / num2
        print(f"The Quotient of {num1}/{num2} = {quotient}")
        break
    except ValueError as e:
        print("You gave wrong input type, Please enter the numbers again")
        print(e)
    except ZeroDivisionError as e:
        print("Dont divide by zero, Please enter the numbers again")
        print(e)
print("Few lines below")

# %% [markdown]
# ### Notebook Tasks Structure

# %%
# Task 1 Placeholder Structure
# Task: Get numbers, ask for index, handle ValueError and IndexError via nested blocks.
pass

# %%
# Task 3 Placeholder Structure
student = {
    "name": "Irine",
    "age": 25,
    "course": "Python"
}
# Task: Ask user for key, display value, use nested exception handling for invalid input / KeyError.
pass
